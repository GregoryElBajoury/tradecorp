# %%
## 5.2 — Tests unitaires avec pytest

# %%
## Q43 — Installer pytest - Vérifier que pytest est disponible dans le conteneur : docker exec tradecorp_spark pytest --version. Si non, l'installer.
## Indice : docker exec tradecorp_spark pip install pytest

# %%
## Q44 — Créer test_transformer.py - Créer tests/test_transformer.py. Écrire un test qui vérifie que clean_orders() supprime bien les lignes où shipped_date est null.
## Indice : from pyspark.sql import SparkSession / spark = SparkSession.builder.getOrCreate() / df_test = spark.createDataFrame(...)

# %%
# Q45 — Test sur sous_total - Écrire un test qui vérifie que add_sous_total() calcule correctement le sous_total. Créer un petit DataFrame de test avec des valeurs connues et vérifier le résultat.
# Indice : Valeur attendue : 10.0 * 2 * (1 - 0.1) = 18.0
