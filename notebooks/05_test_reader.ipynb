# %%
## Notebook 5 — Programmation modulaire et tests unitaires (Jour 4 après-midi + Jour 5)
##💡 On sort des notebooks. Créer des fichiers .py dans le dossier src/. Ces fichiers seront exécutés avec spark-submit depuis le conteneur Docker.

# %%
## 5.1 — Les modules Python

# %%
## Q38 — Créer reader.py - Créer src/reader.py avec une fonction read_csv(spark, path, filename) qui lit un CSV et retourne un DataFrame. Tester en l'important dans un notebook.
##Indice : def read_csv(spark, path, filename): return spark.read.csv(f'{path}/{filename}', header=True, inferSchema=True)

import sys
import os

# Remonte d'un niveau pour atteindre la racine du projet
sys.path.append(os.path.abspath('..'))

from pyspark.sql import SparkSession
from src.reader import read_csv

# Initialisation de la session Spark
spark = SparkSession.builder \
    .appName("TestReaderModule") \
    .getOrCreate()

# Chemin pointant vers data/raw où se trouvent tes CSV
path_sources = "../data/raw"
filename = "orders.csv"

# Test de la fonction
df_test = read_csv(spark, path_sources, filename)
df_test.show(5)
# Out:
# +--------+-----------+-----------+----------+-------------+------------+--------+-------+--------------------+--------------------+--------------+-----------+----------------+------------+
# |order_id|customer_id|employee_id|order_date|required_date|shipped_date|ship_via|freight|           ship_name|        ship_address|     ship_city|ship_region|ship_postal_code|ship_country|
# +--------+-----------+-----------+----------+-------------+------------+--------+-------+--------------------+--------------------+--------------+-----------+----------------+------------+
# |   10248|      VINET|          5|1996-07-04|   1996-08-01|  1996-07-16|       3|  32.38|Vins et alcools C...|  59 rue de l'Abbaye|         Reims|       NULL|           51100|      France|
# |   10249|      TOMSP|          6|1996-07-05|   1996-08-16|  1996-07-10|       1|  11.61|  Toms Spezialitäten|       Luisenstr. 48|       Münster|       NULL|           44087|     Germany|
# ...

# %%
## Q39 — Créer transformer.py - Créer src/transformer.py avec les fonctions : clean_customers(df), clean_orders(df), clean_order_details(df), add_sous_total(df).
## Chaque fonction applique les transformations du jalon 2.

# Importer la fonction depuis le dossier src
from src.reader import read_csv

# Initialiser ou récupérer ta SparkSession
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# Tester la lecture d'un de tes fichiers CSV (par exemple customers.csv)
path_to_data = "/home/jovyan/data/raw" 
df_test = read_csv(spark, path_to_data, "customers.csv")

# Afficher le schéma et un aperçu pour valider que le lecteur fonctionne
df_test.printSchema()
df_test.show(5)
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- company_name: string (nullable = true)
#  |-- contact_name: string (nullable = true)
#  |-- contact_title: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- postal_code: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- phone: string (nullable = true)
#  |-- fax: string (nullable = true)
#
# +-----------+--------------------+------------------+--------------------+--------------------+-----------+------+-----------+-------+--------------+--------------+
# |customer_id|        company_name|      contact_name|       contact_title|             address|       city|region|postal_code|country|         phone|           fax|
# +-----------+--------------------+------------------+--------------------+--------------------+-----------+------+-----------+-------+--------------+--------------+
# ...

# %%
## Q40 — Créer writer.py - Créer src/writer.py avec les fonctions : write_parquet(df, path) et write_postgres(df, table_name, jdbc_url, properties).

# %%
## Q41 — Créer pipeline.py - Créer src/pipeline.py qui importe reader, transformer et writer, et orchestre tout le pipeline de bout en bout.
## Indice : from reader import read_csv / from transformer import clean_orders

# %%
## Q42 — Lancer avec spark-submit - Exécuter le pipeline depuis le terminal Docker : docker exec tradecorp_spark spark-submit /home/jovyan/src/pipeline.py. Vérifier que tout tourne.
## Indice : docker exec -it tradecorp_spark spark-submit /home/jovyan/src/pipeline.py
